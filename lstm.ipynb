# %% [markdown]
# <a href="https://colab.research.google.com/github/vsairam-uc/GenAI-and-LLM/blob/main/lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import json
import re
import string

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Params

# %%
VOCAB_SIZE = 10000
MAX_LEN = 200
EMBEDDING_DIM = 100
N_UNITS = 128
VALIDATION_SPLIT = 0.2
SEED = 42
LOAD_MODEL = False
BATCH_SIZE = 32
EPOCHS = 25

# %% [markdown]
# ## Load the data

# %%
with open("/content/full_format_recipes.json") as json_data:
    recipe_data = json.load(json_data)

# %%
# Filter the dataset
filtered_data = [
    "Recipe for " + x["title"] + " | " + " ".join(x["directions"])
    for x in recipe_data
    if "title" in x
    and x["title"] is not None
    and "directions" in x
    and x["directions"] is not None
]

# %%
# Count the recipes
n_recipes = len(filtered_data)
print(f"{n_recipes} recipes loaded")
# Out:
# 20111 recipes loaded

# %%
example = filtered_data[9]
print(example)
# Out:
# Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas  | Chop enough parsley leaves to measure 1 tablespoon; reserve. Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan, covered, 5 minutes. Meanwhile, sprinkle gelatin over water in a medium bowl and let soften 1 minute. Strain broth through a fine-mesh sieve into bowl with gelatin and stir to dissolve. Season with salt and pepper. Set bowl in an ice bath and cool to room temperature, stirring. Toss ham with reserved parsley and divide among jars. Pour gelatin on top and chill until set, at least 1 hour. Whisk together mayonnaise, mustard, vinegar, 1/4 teaspoon salt, and 1/4 teaspoon pepper in a large bowl. Stir in celery, cornichons, and potatoes. Pulse peas with marjoram, oil, 1/2 teaspoon pepper, and 1/4 teaspoon salt in a food processor to a coarse mash. Layer peas, then potato salad, over ham.

# %% [markdown]
# ## Tokenize the data

# %%
# Pad the punctuation, to treat them as separate 'words'
def pad_punctuation(s):
    s = re.sub(f"([{string.punctuation}])", r" \1 ", s)
    s = re.sub(" +", " ", s)
    return s


text_data = [pad_punctuation(x) for x in filtered_data]

# %%
# Display an example of a recipe
example_data = text_data[9]
example_data
# Out:
# 'Recipe for Ham Persillade with Mustard Potato Salad and Mashed Peas | Chop enough parsley leaves to measure 1 tablespoon ; reserve . Chop remaining leaves and stems and simmer with broth and garlic in a small saucepan , covered , 5 minutes . Meanwhile , sprinkle gelatin over water in a medium bowl and let soften 1 minute . Strain broth through a fine - mesh sieve into bowl with gelatin and stir to dissolve . Season with salt and pepper . Set bowl in an ice bath and cool to room temperature , stirring . Toss ham with reserved parsley and divide among jars . Pour gelatin on top and chill until set , at least 1 hour . Whisk together mayonnaise , mustard , vinegar , 1 / 4 teaspoon salt , and 1 / 4 teaspoon pepper in a large bowl . Stir in celery , cornichons , and potatoes . Pulse peas with marjoram , oil , 1 / 2 teaspoon pepper , and 1 / 4 teaspoon salt in a food processor to a coarse mash . Layer peas , then potato salad , over ham . '

# %%
# Convert to a Tensorflow Dataset
text_ds = (
    tf.data.Dataset.from_tensor_slices(text_data)
    .batch(BATCH_SIZE)
    .shuffle(1000)
)

# %%
# Create a vectorisation layer
vectorize_layer = layers.TextVectorization(
    standardize="lower",
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=MAX_LEN + 1,
)

# %%
# Adapt the layer to the training set
vectorize_layer.adapt(text_ds)
vocab = vectorize_layer.get_vocabulary()

# %%
# Display some token:word mappings
for i, word in enumerate(vocab[:10]):
    print(f"{i}: {word}")
# Out:
# 0:
# 1: [UNK]
# 2: .
# 3: ,
# 4: and
# 5: to
# 6: in
# 7: the
# 8: with
# 9: a

# %%
# Display the same example converted to ints
example_tokenised = vectorize_layer(example_data)
print(example_tokenised.numpy())
# Out:
# [  26   16  557    1    8  298  335  189    4 1054  494   27  332  228
#   235  262    5  594   11  133   22  311    2  332   45  262    4  671
#     4   70    8  171    4   81    6    9   65   80    3  121    3   59
#    12    2  299    3   88  650   20   39    6    9   29   21    4   67
#   529   11  164    2  320  171  102    9  374   13  643  306   25   21
#     8  650    4   42    5  931    2   63    8   24    4   33    2  114
#    21    6  178  181 1245    4   60    5  140  112    3   48    2  117
#   557    8  285  235    4  200  292  980    2  107  650   28   72    4
#   108   10  114    3   57  204   11  172    2   73  110  482    3  298
#     3  190    3   11   23   32  142   24    3    4   11   23   32  142
#    33    6    9   30   21    2   42    6  353    3 3224    3    4  150
#     2  437  494    8 1281    3   37    3   11   23   15  142   33    3
#     4   11   23   32  142   24    6    9  291  188    5    9  412  572
#     2  230  494    3   46  335  189    3   20  557    2    0    0    0
#     0    0    0    0    0]

# %% [markdown]
# ## Create Training Set

# %%
# Create the training set of recipes and the same text shifted by one word
def prepare_inputs(text):
    text = tf.expand_dims(text, -1)
    tokenized_sentences = vectorize_layer(text)
    x = tokenized_sentences[:, :-1]
    y = tokenized_sentences[:, 1:]
    return x, y


train_ds = text_ds.map(prepare_inputs)

# %% [markdown]
# ## Build LSTM

# %%
inputs = layers.Input(shape=(None,), dtype="int32")
x = layers.Embedding(VOCAB_SIZE, EMBEDDING_DIM)(inputs)
x = layers.LSTM(N_UNITS, return_sequences=True)(x)
outputs = layers.Dense(VOCAB_SIZE, activation="softmax")(x)
lstm = models.Model(inputs, outputs)
lstm.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, None)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ embedding (Embedding)                │ (None, None, 100)           │       1,000,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, None, 128)           │         117,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, None, 10000)         │       1,290,000 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,407,248 (9.18 MB)
#  Trainable params: 2,407,248 (9.18 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
if LOAD_MODEL:
    # model.load_weights('./models/model')
    lstm = models.load_model("./models/lstm", compile=False)

# %% [markdown]
# ## Train LSTM

# %%
loss_fn = losses.SparseCategoricalCrossentropy()
lstm.compile("adam", loss_fn)

# %%
# Create a TextGenerator checkpoint
class TextGenerator(callbacks.Callback):
    def __init__(self, index_to_word, top_k=10):
        self.index_to_word = index_to_word
        self.word_to_index = {
            word: index for index, word in enumerate(index_to_word)
        }  # <1>

    def sample_from(self, probs, temperature):  # <2>
        probs = probs ** (1 / temperature)
        probs = probs / np.sum(probs)
        return np.random.choice(len(probs), p=probs), probs

    def generate(self, start_prompt, max_tokens, temperature):
        start_tokens = [
            self.word_to_index.get(x, 1) for x in start_prompt.split()
        ]  # <3>
        sample_token = None
        info = []
        while len(start_tokens) < max_tokens and sample_token != 0:  # <4>
            x = np.array([start_tokens])
            y = self.model.predict(x, verbose=0)  # <5>
            sample_token, probs = self.sample_from(y[0][-1], temperature)  # <6>
            info.append({"prompt": start_prompt, "word_probs": probs})
            start_tokens.append(sample_token)  # <7>
            start_prompt = start_prompt + " " + self.index_to_word[sample_token]
        print(f"\ngenerated text:\n{start_prompt}\n")
        return info

    def on_epoch_end(self, epoch, logs=None):
        self.generate("recipe for", max_tokens=100, temperature=1.0)

# %%
# Create a model save checkpoint
model_checkpoint_callback = callbacks.ModelCheckpoint(
    filepath="./checkpoint/checkpoint.weights.h5",
    save_weights_only=True,
    save_freq="epoch",
    verbose=0,
)

tensorboard_callback = callbacks.TensorBoard(log_dir="./logs")

# Tokenize starting prompt
text_generator = TextGenerator(vocab)

# %%
lstm.fit(
    train_ds,
    epochs=EPOCHS,
    callbacks=[model_checkpoint_callback, tensorboard_callback, text_generator],
)
# Out:
# Epoch 1/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.5017
# generated text:
# recipe for sweet and - cherry cobbler with tropical fruits and cream cheese | melt chocolate in heavy large saucepan over medium heat . add hearts and water stick to saucepan . add salt flour . stir in 1 / 2 cup sugar . cover and simmer until plums are small , stirring occasionally , about 15 minutes . pour 3 / 4 cup cranberries into large mixture measuring cup . sprinkle flour over all sides of white and stir until melted . add nut mixture to skillet and whisk in butter until melted . remove springform pan sides and
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - loss: 1.5017
# Epoch 2/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.4876
# generated text:
# recipe for asian pork soup with pork , new tomatoes , black chili , and freshly grated herbs | place saffron threads in heavy - duty resealable plastic bag ; shake vigorously . add remaining 1 tablespoon oil , thyme , 2 teaspoons salt , and peppercorns . transfer to 9 cups to 12 x 2 - inch springform pan . roast until marinade just just warm enough to touch and dry - juices , about 25 minutes . transfer to small plate . season with salt . cut peel and cutting into the plantains in half ; peel and
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.4877
# Epoch 3/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4855
# generated text:
# recipe for yellow , beetroot , and mint salad | 1 . pat the hens dry and sprinkle the spice mixture , transfer it lightly , both sides and the peppers , and let rest for 1 hour . turn the heat and add the onion banana and syrup . let the meat stand for 2 hours or until the liquid is thickened . can be refrigerated for 2 months in a punch .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 32s 50ms/step - loss: 1.4855
# Epoch 4/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4687
# generated text:
# recipe for banana - roasted shrimp | preheat the oven to 225°f with rack in the fridge for dipping . soak the onion slightly at least 10 ; cover them with plastic wrap near the turkey . preheat the oven to 40 briquets on each side . rub the in the feed tube and backbone . generously dust the the sheet with a damp cloth ( fats into a tiny pan ) , then create sure often when the cap gets translucent . flour the mixture is very hot—almost al dente , you should have 1 / 4 inch thick
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.4687
# Epoch 5/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4717
# generated text:
# recipe for coconut - crusted salmon with pine frosting of yogurt coconut sauce | combine first 4 ingredients in small bowl . do ahead : butter can be made 1 day ahead . cover ; refrigerated . whisk mayonnaise , orange juice , and vinegar in medium bowl . process just until frozen , at least 6 hours . remove and reserve . do ahead : can be made 6 hours ahead . refrigerate . serve warm or at room temperature .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - loss: 1.4717
# Epoch 6/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.4622
# generated text:
# recipe for todd ' s mushroom pasta ii | in large deep skillet , heat heavy wok over high heat until the fat has rendered and browns ( about 20 minutes ) . add 2 and roll to 2 or 3 / 4 " - thyme mixture or 2 . heat the oil over medium heat until it shimmers , then sauté spinach over moderately high heat until golden brown , 2 - to 5 minutes . add half of the soup and parsley and stir - fry for 3 to 6 minutes . cook for 1 minute . meanwhile
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.4622
# Epoch 7/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4530
# generated text:
# recipe for vegetable stock | in a medium saucepan heat remaining cup wine and salt to taste over moderate heat until hot but not smoking , then add miso , carrots , figs , orange juice , 1 tbsp honey to make pan , and reduce heat to low ; place lamb in pan . roast chicken in middle of oven until thermometer registers 350°f and with an instant - read thermometer inserted into the center registers 165°f , white , 1 40 minutes . turn to heat and cook burgers on a work surface for about 3 minutes more
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 40s 54ms/step - loss: 1.4530
# Epoch 8/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4512
# generated text:
# recipe for crispy curried asparagus salad | in a rolling boil beans , in a small saucepan melt butter and sesame oil and poach at 1 batch until reduced to about 1 / 2 cup , then remove pan from heat and whisk in some parsley . put skillet on a round of foil . carefully lift chicken with glaze from skillet and cook potatoes until crisp - tender , about 3 minutes .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 33s 53ms/step - loss: 1.4512
# Epoch 9/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4388
# generated text:
# recipe for scallops with ginger - ginger sauce , feta first , mint and bacon | cook onion until softened and thick and pale golden , about 4 minutes . add wine and lemon juice and bring to a boil . simmer , partially covered , stirring occasionally , until crisp - tender , about 5 minutes . reduce heat to low and cool slightly . preheat oven to 350° . heat cream with an electric coffee / or 2 - 1 ounce spice mix sauce over and fold in fish . pour milk in hot water and stir in
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.4388
# Epoch 10/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4376
# generated text:
# recipe for veal tenderloin | preheat oven to 400°f . place yams in single layer on prepared baking sheet . sprinkle with salt and roast until tender and soft , stirring occasionally , about 12 minutes . sprinkle both sides lightly with salt . place baking sheet and roast until bread softens , about 15 minutes . turn chicken over , then set remaining 1 / 2 cup poaching liquid to roasting pan to distribute fat . roast until vegetables are tender and golden and crisp , about 10 minutes . cool slightly . peel and parsley snaps ; chop
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.4376
# Epoch 11/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.4299
# generated text:
# recipe for balsamic pecan pie with redeye gravy | place loaf pan over . reduce oven temperature to 300°f . generously butter large rimmed baking sheet . heat cream in large nonstick skillet over medium - high heat . add freshly ground melted butter and microwave , stirring constantly until deep clumps , about 2 minutes . transfer to 9 - inch - diameter glass pie dish . melt remaining 1 tablespoon butter in same skillet over medium heat . add apples and madeira ; sauté 30 seconds . add 1 / 4 cup remaining sausage mixture ; sprinkle with
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 36s 57ms/step - loss: 1.4299
# Epoch 12/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4200
# generated text:
# recipe for thai - pea soup with portobellos bread | preheat oven to 375°f . spray large roasting pan with nonstick spray . line dish with foil . stir all ingredients in another medium saucepan . melt butter in large skillet over medium - low heat . add cheese and mash garlic to roux mixture about 2 minutes . season to taste with salt and pepper . cool completely . ( can be prepared 2 days ahead . cover and let stand at room temperature . rewarm over low heat before using . ) place tortillas in prepared pan (
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.4200
# Epoch 13/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4195
# generated text:
# recipe for mango - braised chicken with red cabbage | cover zucchini with half of celery and toss with 1 / 4 cup onion to coat . cover and chill at least 4 hours . peel and core cabbage and radish dry . heat 1 / 2 teaspoon oil in a large pan over moderately high heat and add all but about 3 3 / 8 teaspoon salt . put skillet on a sheet of foil , in 4 pieces at a time , then fry spinach 1 tablespoon oil until pan is limp and dry , 8 to 15
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 55ms/step - loss: 1.4195
# Epoch 14/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.4207
# generated text:
# recipe for wasabi cod on angel hair with shrimp , shiitake bok choy , and mint | whisk 2 tablespoons mayonnaise and mustard in a food processor . gradually add parsley ; season with salt and pepper and toss to coat . spread onions on top . toss well with salad ; top with salad and sesame . serve with steamed beans .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 39s 51ms/step - loss: 1.4207
# Epoch 15/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4099
# generated text:
# recipe for summer blueberry and gruyère cake on boiled eggs blossoms | preheat oven to 350°f . whisk together sour cream , apple , vanilla , and sugar in a food processor until smooth . pour custard through fine sieve into a metal bowl toss with fork . add plums in a 12 - inch heavy skillet , then butter and cook , stirring occasionally , until it is pale golden , about 3 minutes . add apple juice and 1 / 4 cup sugar to a boil and chill on a baking sheet until tops are golden , about
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.4099
# Epoch 16/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4022
# generated text:
# recipe for chipotle rolls | heat 1 tablespoon oil in a large deep skillet over medium - low . add shallots , garlic , and ginger . cook until they begin to brown , about 2 minutes . add chopped ginger , fennel , and star anise and cook , stirring and breaking up with a wooden spoon , until broth is reduced by 1 to 2 1 / 4 cups and add 2 quarts water and reduce heat to low . simmer 10 minutes or until slightly thickened . keep warm , covered , then discard solids in pan
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 56ms/step - loss: 1.4022
# Epoch 17/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4010
# generated text:
# recipe for cider - yogurt mayonnaise | prepare grill . combine mayonnaise and chile starch , dry adobo , cumin , and cayenne in a bowl . pat pork mixture with your fingers to another wooden . arrange steak slices in a shallow baking pan or broil broiler with 2 teaspoons butter , then top if desired . arrange lamb on a platter , overlapping completely in remaining ramekins . pick over turkey to level more . sprinkle with kosher salt and remaining 1 tablespoon coconut . marinate shrimp , uncovered , turning coating over hour , then chill ,
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.4010
# Epoch 18/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3940
# generated text:
# recipe for rhubarb , and walnut tart | stir ingredients in medium metal bowl to blend . add butter and cherries . using tart pan , transfer dough to prepared baking pan and smooth top . press chilled almost about 1 / 2 cup rhubarb for fork 1 / 4 / 4 cup to seal . combine remaining 1 tablespoon sugar , 1 / 3 cup sauce , cinnamon , 2 tablespoons sugar , and brown sugar in another medium bowl to blend until mixture resembles using . add pears . let macerate 30 minutes . reduce oven temperature to
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 36s 57ms/step - loss: 1.3940
# Epoch 19/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.4026
# generated text:
# recipe for glazed bacon - cider quiche | preheat oven to 350°f . mix sugar and 1 / 2 teaspoon mint in heavy medium saucepan . bring to boil , stirring occasionally , about 1 minute . add plums ; bring to boil ; cover and let steep cool 20 minutes . using slotted spoon , transfer filling to 9x5x3 - inch baking pan . spoon custard into crust . reduce heat to medium . position rack in center of oven and preheat to dry . sprinkle gelatin into with salt . mix honey mixture into small bowl and chill
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.4026
# Epoch 20/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3951
# generated text:
# recipe for arugula salad with peanut sauce | stir together soy sauce , onion , garlic , pepper , and mustard in a 10 - inch skillet with 2 teaspoons salt and sauté over moderately low heat , stirring constantly , for 3 minutes . sprinkle yeast over with a pinch of sugar and slowly bring milk mixture to a boil . beat half of oil in a saucepan until hot but not 3 more than about 5 cups . add egg yolks , 1 at a time , and cook remaining eggs , whisking often , until whites are
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 55ms/step - loss: 1.3951
# Epoch 21/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3885
# generated text:
# recipe for coconut milk ice cream terrine with fig sauce | with a shallow crust stand , in bottom of another shallow dish , or in a food processor finely chop gingerroot , blend , 1 / 4 cup butter , 1 cup flour by 2 tablespoons sugar , 1 / 4 cup water , and 1 / 4 cup water until mixture begins to soften and add more ice water , in 1 piece at a time . stir in flour mixture and white mixture over sweet , stirring until firm , about 4 minutes . stir in flour
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 37s 59ms/step - loss: 1.3885
# Epoch 22/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3849
# generated text:
# recipe for braised - lamb tagine with lemon | finely chop almonds in processor . blend olive paste , orange juice and salt in large saucepan over medium - high heat until sugar dissolves , scraping down and juices form . mix in 3 cups water , almonds , lemon peel , and madeira . bring to boil and simmer 25 minutes . season ribs with salt and pepper . cool completely . preheat oven to 450°f . toss mangoes with half and tangerines . season with salt and pepper ; toss to coat . cover and chill 1 hour
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - loss: 1.3849
# Epoch 23/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3778
# generated text:
# recipe for arugula salad with tomatoes , radishes and tomato - butter sauce | in a large skillet simmer the lettuce well in a large bowl until crisp - tender , 10 to 15 minutes , and cool them slightly , then stir in the soy sauce , the mustard , and the cornstarch . in another large bowl whisk together the soy sauce , the sugar , the paprika , and the parsley , the dill , the chicken , the green , and the black beans , bring the mixture to the boil , stirring to combine .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 35s 56ms/step - loss: 1.3778
# Epoch 24/25
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.3736
# generated text:
# recipe for fava bean soup with tomato , and crispy goat cheese | place leeks in large bowl . rinse chicken and water to measure 1 cup water and shaking off tap excess moisture . chop onion , chopped tomatoes , peppercorns , and thyme . stir in ginger and cinnamon . remove from heat . mix first 10 ingredients in large bowl . add 1 / 4 cup water and blend until very smooth ; season with salt . refrigerate until tomato slightly chilled , about 2 hours . mix garbanzo beans , eggplant , eggs , corn kernels
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 34s 55ms/step - loss: 1.3736
# Epoch 25/25
# 628/629 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.3704
# generated text:
# recipe for vanilla - coconut fish | process mayonnaise and mayonnaise according to manufacturer ' s instructions .
#
# 629/629 ━━━━━━━━━━━━━━━━━━━━ 30s 48ms/step - loss: 1.3704

# %%
# !mkdir models
# Save the final model
lstm.save("./models/lstm.keras")
# Out:
# mkdir: cannot create directory ‘models’: File exists

# %% [markdown]
# ## Generate Text with LSTM

# %%
def print_probs(info, vocab, top_k=5):
    for i in info:
        print(f"\nPROMPT: {i['prompt']}")
        word_probs = i["word_probs"]
        p_sorted = np.sort(word_probs)[::-1][:top_k]
        i_sorted = np.argsort(word_probs)[::-1][:top_k]
        for p, i in zip(p_sorted, i_sorted):
            print(f"{vocab[i]}:   \t{np.round(100*p,2)}%")
        print("--------\n")

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=1.0
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 4 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	39.85%
# 4:   	36.99%
# 8:   	11.71%
# 3:   	5.38%
# 1:   	0.79%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4
# cup:   	57.86%
# inch:   	20.74%
# teaspoon:   	7.01%
# of:   	4.94%
# -:   	1.58%
# --------

# %%
info = text_generator.generate(
    "recipe for roasted vegetables | chop 1 /", max_tokens=10, temperature=0.2
)
# Out:
# generated text:
# recipe for roasted vegetables | chop 1 / 4 cup

# %%
print_probs(info, vocab)
# Out:
# PROMPT: recipe for roasted vegetables | chop 1 /
# 2:   	59.15%
# 4:   	40.71%
# 8:   	0.13%
# 3:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetables | chop 1 / 4
# cup:   	99.41%
# inch:   	0.59%
# teaspoon:   	0.0%
# of:   	0.0%
# -:   	0.0%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=1.0
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | combine
#
#
# PROMPT: recipe for chocolate ice cream |
# combine:   	22.65%
# whisk:   	10.21%
# bring:   	8.94%
# in:   	7.4%
# stir:   	7.31%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=7, temperature=0.2
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | combine
#
#
# PROMPT: recipe for chocolate ice cream |
# combine:   	96.42%
# whisk:   	1.8%
# bring:   	0.92%
# in:   	0.36%
# stir:   	0.34%
# --------

# %% [markdown]
# ## Experiment with different values of temperature

# %%
info = text_generator.generate(
    "recipe for roasted vegetable |", max_tokens=100, temperature=0.5
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a dry large skillet and add oil .
#
#
# PROMPT: recipe for roasted vegetable |
# preheat:   	90.17%
# 1:   	3.62%
# heat:   	2.78%
# char:   	0.94%
# put:   	0.44%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat
# oven:   	99.94%
# broiler:   	0.05%
# the:   	0.01%
# a:   	0.0%
# all:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven
# to:   	100.0%
# (:   	0.0%
# and:   	0.0%
# .:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to
# 450°f:   	53.22%
# 400°f:   	17.02%
# 350°f:   	12.12%
# 425°f:   	10.35%
# 375°f:   	5.05%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f
# .:   	88.1%
# with:   	11.88%
# and:   	0.02%
# ;:   	0.0%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f .
# toss:   	44.65%
# in:   	10.93%
# cut:   	6.6%
# heat:   	4.78%
# arrange:   	4.78%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine
# first:   	56.7%
# garlic:   	10.83%
# tomatoes:   	5.46%
# fennel:   	3.52%
# oil:   	2.68%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel
# ,:   	86.18%
# and:   	8.82%
# bulb:   	3.64%
# seeds:   	0.88%
# oil:   	0.31%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel ,
# garlic:   	32.32%
# onion:   	15.13%
# carrots:   	13.67%
# fennel:   	10.26%
# celery:   	6.3%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots
# ,:   	99.89%
# and:   	0.11%
# with:   	0.0%
# (:   	0.0%
# or:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots ,
# and:   	53.36%
# celery:   	15.71%
# garlic:   	10.48%
# onion:   	9.2%
# oil:   	3.11%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery
# ,:   	99.18%
# and:   	0.63%
# root:   	0.17%
# leaves:   	0.01%
# seeds:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery ,
# and:   	61.98%
# garlic:   	11.97%
# celery:   	7.47%
# onion:   	3.69%
# carrots:   	3.62%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and
# garlic:   	67.27%
# celery:   	13.58%
# carrots:   	7.37%
# onion:   	4.4%
# fennel:   	3.8%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic
# in:   	99.96%
# on:   	0.04%
# into:   	0.0%
# and:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in
# a:   	97.03%
# large:   	1.9%
# bowl:   	0.41%
# medium:   	0.27%
# small:   	0.26%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a
# large:   	89.07%
# shallow:   	4.71%
# small:   	4.41%
# bowl:   	0.75%
# medium:   	0.65%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large
# bowl:   	97.58%
# shallow:   	1.05%
# roasting:   	0.73%
# baking:   	0.39%
# pot:   	0.08%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl
# .:   	89.95%
# and:   	6.11%
# ;:   	3.83%
# ,:   	0.05%
# with:   	0.04%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl .
# add:   	79.45%
# toss:   	8.94%
# season:   	3.85%
# drizzle:   	2.32%
# sprinkle:   	1.5%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add
# enough:   	25.8%
# oil:   	24.61%
# onion:   	7.75%
# water:   	5.72%
# remaining:   	4.29%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough
# water:   	68.59%
# oil:   	18.89%
# cold:   	5.63%
# onion:   	1.31%
# of:   	1.26%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water
# to:   	100.0%
# and:   	0.0%
# as:   	0.0%
# just:   	0.0%
# or:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to
# cover:   	97.2%
# reach:   	1.99%
# come:   	0.2%
# seal:   	0.18%
# coat:   	0.07%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach
# 1:   	44.25%
# halfway:   	42.15%
# depth:   	3.53%
# a:   	3.28%
# 30:   	2.9%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway
# up:   	99.99%
# with:   	0.0%
# halfway:   	0.0%
# from:   	0.0%
# over:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up
# sides:   	96.23%
# side:   	1.49%
# inside:   	0.64%
# to:   	0.41%
# bones:   	0.3%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides
# of:   	99.99%
# .:   	0.0%
# down:   	0.0%
# and:   	0.0%
# up:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of
# dish:   	55.54%
# bowl:   	12.82%
# bag:   	9.67%
# pan:   	9.36%
# 9:   	3.98%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl
# .:   	53.6%
# to:   	40.0%
# and:   	2.59%
# ,:   	1.67%
# ;:   	0.81%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl .
# seal:   	45.83%
# add:   	16.72%
# roast:   	11.65%
# cover:   	5.02%
# sprinkle:   	4.96%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover
# with:   	82.55%
# and:   	10.45%
# dish:   	4.49%
# ;:   	0.63%
# pot:   	0.47%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with
# foil:   	49.83%
# plastic:   	41.52%
# 2:   	1.8%
# lid:   	1.39%
# remaining:   	1.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil
# and:   	81.1%
# .:   	11.31%
# ;:   	4.77%
# ,:   	2.64%
# or:   	0.1%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and
# roast:   	51.54%
# seal:   	30.35%
# bake:   	11.41%
# cover:   	4.25%
# let:   	0.56%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal
# tightly:   	78.08%
# .:   	12.65%
# ,:   	4.89%
# and:   	3.03%
# with:   	0.45%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly
# .:   	67.0%
# and:   	17.06%
# ,:   	8.43%
# with:   	6.78%
# ;:   	0.54%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with
# foil:   	98.6%
# plastic:   	1.35%
# aluminum:   	0.03%
# lid:   	0.01%
# kitchen:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil
# .:   	54.6%
# and:   	38.46%
# ,:   	5.86%
# ;:   	0.99%
# (:   	0.04%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil .
# roast:   	57.7%
# bake:   	40.54%
# cover:   	0.55%
# let:   	0.47%
# cook:   	0.21%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast
# until:   	87.02%
# turkey:   	2.91%
# vegetables:   	2.79%
# 20:   	2.75%
# ,:   	1.88%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables
# until:   	96.9%
# in:   	0.69%
# ,:   	0.69%
# 20:   	0.4%
# at:   	0.32%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until
# tender:   	93.62%
# just:   	2.67%
# thermometer:   	2.1%
# vegetables:   	0.38%
# very:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender
# ,:   	90.46%
# and:   	9.17%
# when:   	0.3%
# but:   	0.07%
# .:   	0.01%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender ,
# about:   	98.36%
# 25:   	0.25%
# 20–25:   	0.21%
# 1:   	0.15%
# turning:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about
# 1:   	41.35%
# 20:   	17.85%
# 30:   	12.52%
# 40:   	5.35%
# 25:   	4.76%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25
# minutes:   	99.94%
# hours:   	0.03%
# -:   	0.03%
# to:   	0.01%
# ,:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes
# .:   	99.74%
# ,:   	0.23%
# (:   	0.02%
# ;:   	0.0%
# or:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes .
# meanwhile:   	45.14%
# transfer:   	21.55%
# remove:   	14.56%
# cool:   	4.16%
# let:   	2.54%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile
# ,:   	100.0%
# .:   	0.0%
# and:   	0.0%
# (:   	0.0%
# before:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile ,
# heat:   	28.5%
# cook:   	21.58%
# combine:   	12.18%
# whisk:   	6.13%
# stir:   	4.67%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir
# together:   	95.37%
# cumin:   	1.0%
# remaining:   	0.97%
# parsley:   	0.33%
# garlic:   	0.32%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together
# remaining:   	27.36%
# vinegar:   	22.89%
# lemon:   	9.77%
# garlic:   	7.99%
# mustard:   	4.44%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining
# 1:   	66.97%
# ingredients:   	19.38%
# 2:   	11.55%
# 3:   	1.6%
# tablespoon:   	0.22%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1
# /:   	78.12%
# tablespoon:   	11.08%
# 1:   	10.54%
# teaspoon:   	0.18%
# cup:   	0.07%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon
# butter:   	53.27%
# oil:   	37.26%
# thyme:   	2.26%
# parsley:   	1.88%
# water:   	0.81%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter
# ,:   	59.29%
# and:   	40.3%
# with:   	0.28%
# .:   	0.11%
# in:   	0.01%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter ,
# 1:   	67.62%
# garlic:   	6.61%
# 2:   	4.54%
# mustard:   	3.27%
# vinegar:   	2.9%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar
# ,:   	99.8%
# and:   	0.2%
# .:   	0.0%
# or:   	0.0%
# mixture:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar ,
# and:   	88.72%
# garlic:   	2.62%
# sugar:   	2.52%
# vinegar:   	1.37%
# oil:   	1.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and
# 1:   	48.89%
# salt:   	19.09%
# remaining:   	8.14%
# pepper:   	6.12%
# mustard:   	4.07%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt
# in:   	80.86%
# and:   	17.17%
# .:   	0.9%
# to:   	0.87%
# until:   	0.07%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in
# a:   	99.98%
# medium:   	0.01%
# an:   	0.0%
# bowl:   	0.0%
# small:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a
# small:   	38.12%
# blender:   	26.13%
# large:   	15.04%
# bowl:   	15.04%
# food:   	3.71%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small
# bowl:   	99.9%
# saucepan:   	0.07%
# heavy:   	0.01%
# measuring:   	0.0%
# ,:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl
# .:   	54.48%
# ,:   	16.92%
# to:   	16.69%
# until:   	5.46%
# and:   	5.42%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl ,
# then:   	96.44%
# pressing:   	2.25%
# stirring:   	0.93%
# covered:   	0.12%
# reserving:   	0.11%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then
# add:   	55.66%
# season:   	9.58%
# let:   	8.9%
# stir:   	6.22%
# whisk:   	4.27%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash
# with:   	68.81%
# to:   	10.93%
# in:   	6.31%
# until:   	4.64%
# garlic:   	3.24%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic
# with:   	85.49%
# to:   	10.51%
# mixture:   	2.7%
# until:   	0.48%
# and:   	0.24%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with
# salt:   	61.49%
# 1:   	25.25%
# remaining:   	5.67%
# a:   	4.24%
# your:   	0.61%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt
# and:   	93.34%
# to:   	2.67%
# .:   	2.07%
# ,:   	1.71%
# until:   	0.21%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and
# pepper:   	99.99%
# black:   	0.0%
# sugar:   	0.0%
# remaining:   	0.0%
# cayenne:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper
# to:   	99.92%
# .:   	0.07%
# ,:   	0.0%
# and:   	0.0%
# in:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to
# taste:   	100.0%
# oil:   	0.0%
# a:   	0.0%
# blend:   	0.0%
# heat:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste
# .:   	54.68%
# in:   	33.43%
# and:   	9.65%
# until:   	1.2%
# ,:   	0.97%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in
# a:   	92.58%
# same:   	2.15%
# batches:   	1.38%
# oil:   	1.23%
# 2:   	1.08%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a
# blender:   	64.71%
# food:   	13.95%
# small:   	10.57%
# large:   	6.82%
# bowl:   	3.37%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food
# processor:   	99.92%
# mill:   	0.07%
# storage:   	0.01%
# spice:   	0.0%
# grinder:   	0.0%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor
# until:   	97.65%
# .:   	1.17%
# and:   	0.63%
# ,:   	0.52%
# or:   	0.01%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until
# smooth:   	92.22%
# finely:   	3.96%
# very:   	2.53%
# coarsely:   	0.56%
# mixture:   	0.21%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth
# .:   	93.8%
# ,:   	5.14%
# and:   	0.51%
# (:   	0.44%
# ;:   	0.07%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth .
# add:   	36.85%
# transfer:   	22.65%
# season:   	11.34%
# heat:   	8.85%
# stir:   	5.86%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add
# remaining:   	41.58%
# oil:   	21.62%
# butter:   	10.48%
# 1:   	4.89%
# tomatoes:   	2.77%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1
# /:   	89.15%
# tablespoon:   	5.35%
# cup:   	4.27%
# 1:   	0.87%
# teaspoon:   	0.26%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon
# oil:   	79.94%
# butter:   	16.58%
# salt:   	1.55%
# water:   	0.99%
# lemon:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil
# and:   	57.96%
# to:   	22.24%
# ,:   	11.85%
# in:   	6.53%
# ;:   	0.65%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to
# a:   	95.58%
# skillet:   	3.13%
# make:   	0.21%
# remaining:   	0.13%
# oil:   	0.12%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a
# slow:   	51.22%
# dry:   	20.0%
# bowl:   	11.73%
# small:   	7.39%
# large:   	3.9%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a dry
# heavy:   	27.66%
# skillet:   	26.94%
# ingredients:   	16.41%
# large:   	14.12%
# small:   	3.7%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a dry large
# skillet:   	96.84%
# heavy:   	1.34%
# bowl:   	1.07%
# nonstick:   	0.35%
# saucepan:   	0.12%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a dry large skillet
# .:   	52.04%
# and:   	21.01%
# ;:   	12.9%
# in:   	6.83%
# ,:   	3.56%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a dry large skillet and
# cook:   	65.08%
# stir:   	18.04%
# heat:   	6.25%
# sauté:   	5.57%
# toast:   	1.62%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a dry large skillet and add
# oil:   	31.42%
# garlic:   	27.87%
# 1:   	9.88%
# remaining:   	8.78%
# butter:   	3.78%
# --------
#
#
# PROMPT: recipe for roasted vegetable | preheat oven to 450°f . combine fennel , carrots , celery , and garlic in a large bowl . add enough water to reach halfway up sides of bowl . cover with foil and seal tightly with foil . roast vegetables until tender , about 25 minutes . meanwhile , stir together remaining 1 tablespoon butter , vinegar , and salt in a small bowl , then mash garlic with salt and pepper to taste in a food processor until smooth . add 1 tablespoon oil to a dry large skillet and add oil
# .:   	56.11%
# and:   	18.87%
# ,:   	10.48%
# in:   	10.29%
# to:   	3.68%
# --------

# %%
info = text_generator.generate(
    "recipe for roasted vegetable |", max_tokens=100, temperature=5.0
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting matzoh basic szechwan slightly oranges parchment lard
#
#
# PROMPT: recipe for roasted vegetable |
# preheat:   	0.34%
# 1:   	0.25%
# heat:   	0.24%
# char:   	0.22%
# put:   	0.2%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots
# ,:   	0.32%
# and:   	0.31%
# ::   	0.31%
# can:   	0.25%
# with:   	0.18%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole
# ::   	0.5%
# with:   	0.49%
# and:   	0.36%
# ,:   	0.3%
# can:   	0.28%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen
# and:   	0.75%
# with:   	0.53%
# in:   	0.53%
# ::   	0.35%
# [UNK]:   	0.25%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters
# in:   	0.54%
# may:   	0.52%
# ):   	0.42%
# of:   	0.4%
# can:   	0.39%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly
# into:   	0.4%
# with:   	0.37%
# in:   	0.31%
# as:   	0.28%
# and:   	0.27%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either
# in:   	0.2%
# large:   	0.15%
# garlic:   	0.15%
# long:   	0.15%
# between:   	0.13%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks
# if:   	0.4%
# between:   	0.34%
# on:   	0.32%
# in:   	0.3%
# through:   	0.3%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag
# on:   	0.28%
# in:   	0.22%
# and:   	0.22%
# between:   	0.2%
# onto:   	0.2%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly
# ):   	0.41%
# in:   	0.32%
# and:   	0.3%
# .:   	0.27%
# on:   	0.26%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin
# stems:   	0.22%
# leaves:   	0.22%
# heads:   	0.21%
# head:   	0.2%
# cloves:   	0.19%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince
# ):   	0.41%
# threads:   	0.18%
# .:   	0.18%
# head:   	0.17%
# with:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe
# head:   	0.32%
# ):   	0.25%
# .:   	0.22%
# heads:   	0.2%
# in:   	0.2%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta
# ):   	0.55%
# head:   	0.23%
# between:   	0.18%
# on:   	0.17%
# under:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly
# ):   	0.24%
# in:   	0.2%
# slice:   	0.18%
# head:   	0.17%
# and:   	0.13%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele
# ):   	0.3%
# head:   	0.19%
# heads:   	0.18%
# in:   	0.17%
# stalks:   	0.16%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try
# or:   	0.3%
# ):   	0.23%
# under:   	0.23%
# in:   	0.21%
# on:   	0.2%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops
# under:   	0.45%
# on:   	0.43%
# in:   	0.4%
# .:   	0.37%
# and:   	0.34%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla
# ):   	0.14%
# flat:   	0.13%
# and:   	0.13%
# a:   	0.12%
# its:   	0.12%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai
# out:   	0.19%
# away:   	0.15%
# ':   	0.14%
# from:   	0.12%
# bones:   	0.11%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved
# lobster:   	0.22%
# lemons:   	0.21%
# lemon:   	0.19%
# pot:   	0.18%
# chicken:   	0.18%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe
# pot:   	0.2%
# jars:   	0.19%
# lemons:   	0.18%
# pieces:   	0.18%
# meat:   	0.18%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine
# head:   	0.23%
# ,:   	0.21%
# or:   	0.2%
# pot:   	0.19%
# tips:   	0.18%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach
# ,:   	0.3%
# under:   	0.27%
# and:   	0.26%
# in:   	0.22%
# with:   	0.22%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards
# .:   	0.44%
# ,:   	0.38%
# and:   	0.36%
# or:   	0.24%
# from:   	0.22%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette
# and:   	0.48%
# .:   	0.33%
# ,:   	0.27%
# of:   	0.24%
# layers:   	0.22%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes
# and:   	0.71%
# .:   	0.57%
# ,:   	0.54%
# the:   	0.44%
# ;:   	0.32%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully
# and:   	0.43%
# .:   	0.35%
# with:   	0.25%
# ,:   	0.22%
# if:   	0.2%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight
# .:   	1.18%
# ;:   	0.44%
# or:   	0.4%
# with:   	0.39%
# ,:   	0.39%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed
# .:   	0.42%
# with:   	0.33%
# the:   	0.26%
# ,:   	0.18%
# more:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned
# with:   	0.27%
# [UNK]:   	0.17%
# .:   	0.17%
# in:   	0.15%
# the:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel
# of:   	0.34%
# you:   	0.22%
# cold:   	0.21%
# with:   	0.2%
# using:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins
# .:   	0.72%
# before:   	0.55%
# with:   	0.46%
# and:   	0.4%
# in:   	0.4%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough
# of:   	0.2%
# to:   	0.19%
# cooking:   	0.13%
# .:   	0.13%
# moisture:   	0.12%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed
# with:   	0.23%
# leaves:   	0.23%
# cold:   	0.19%
# to:   	0.17%
# lemon:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack
# with:   	0.7%
# .:   	0.42%
# to:   	0.31%
# liberally:   	0.23%
# before:   	0.23%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped
# with:   	0.3%
# leaves:   	0.2%
# .:   	0.19%
# to:   	0.15%
# garlic:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage
# .:   	0.47%
# leaves:   	0.44%
# together:   	0.44%
# ,:   	0.34%
# with:   	0.33%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly
# .:   	0.6%
# to:   	0.49%
# with:   	0.43%
# ,:   	0.38%
# before:   	0.37%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed
# with:   	0.65%
# them:   	0.58%
# .:   	0.52%
# the:   	0.49%
# it:   	0.46%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem
# artichokes:   	0.26%
# artichoke:   	0.16%
# with:   	0.16%
# carrots:   	0.15%
# cucumbers:   	0.14%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap
# with:   	0.24%
# .:   	0.19%
# the:   	0.16%
# and:   	0.15%
# leaves:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake
# .:   	0.36%
# with:   	0.33%
# ,:   	0.26%
# in:   	0.24%
# (:   	0.24%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink
# .:   	0.49%
# with:   	0.48%
# in:   	0.47%
# ,:   	0.43%
# and:   	0.36%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches
# .:   	0.51%
# ,:   	0.41%
# at:   	0.3%
# on:   	0.3%
# and:   	0.28%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot
# ,:   	0.36%
# .:   	0.36%
# and:   	0.32%
# ones:   	0.22%
# in:   	0.21%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around
# the:   	0.28%
# 1:   	0.17%
# you:   	0.16%
# .:   	0.16%
# end:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked
# .:   	0.39%
# and:   	0.22%
# ,:   	0.21%
# for:   	0.19%
# ;:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps
# .:   	0.79%
# ,:   	0.76%
# and:   	0.45%
# the:   	0.43%
# in:   	0.39%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide
# .:   	0.42%
# ,:   	0.41%
# and:   	0.34%
# in:   	0.32%
# to:   	0.29%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise
# .:   	0.59%
# ,:   	0.33%
# or:   	0.3%
# under:   	0.24%
# in:   	0.23%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near
# .:   	0.16%
# the:   	0.13%
# each:   	0.13%
# stem:   	0.12%
# them:   	0.12%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe
# .:   	0.5%
# ,:   	0.22%
# and:   	0.19%
# (:   	0.18%
# with:   	0.18%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing
# .:   	0.65%
# with:   	0.42%
# ,:   	0.39%
# and:   	0.39%
# ;:   	0.37%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing )
# .:   	0.93%
# with:   	0.53%
# ,:   	0.43%
# and:   	0.33%
# ;:   	0.32%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis
# .:   	0.97%
# ,:   	0.63%
# and:   	0.61%
# (:   	0.59%
# ;:   	0.55%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big
# ,:   	0.31%
# .:   	0.26%
# layers:   	0.19%
# ;:   	0.19%
# enough:   	0.18%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair
# .:   	0.28%
# with:   	0.27%
# ,:   	0.25%
# or:   	0.22%
# and:   	0.21%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps
# .:   	0.56%
# with:   	0.54%
# ,:   	0.44%
# to:   	0.42%
# in:   	0.36%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly
# .:   	0.49%
# with:   	0.46%
# and:   	0.42%
# ,:   	0.39%
# when:   	0.33%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually
# ,:   	0.5%
# and:   	0.35%
# will:   	0.32%
# in:   	0.29%
# is:   	0.28%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove
# any:   	0.31%
# ,:   	0.26%
# and:   	0.24%
# the:   	0.23%
# as:   	0.19%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes
# water:   	0.35%
# ,:   	0.27%
# or:   	0.24%
# and:   	0.23%
# with:   	0.23%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands
# with:   	0.53%
# ,:   	0.48%
# and:   	0.44%
# .:   	0.4%
# ;:   	0.31%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave
# .:   	0.28%
# or:   	0.28%
# ,:   	0.25%
# (:   	0.21%
# with:   	0.21%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole
# ,:   	0.21%
# leaves:   	0.21%
# .:   	0.19%
# and:   	0.18%
# long:   	0.14%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets
# or:   	0.21%
# and:   	0.18%
# half:   	0.17%
# .:   	0.17%
# whole:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped
# -:   	0.52%
# and:   	0.48%
# ,:   	0.32%
# 1:   	0.25%
# .:   	0.24%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8
# pieces:   	0.23%
# -:   	0.18%
# slices:   	0.17%
# ounces:   	0.17%
# to:   	0.16%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls
# of:   	0.41%
# .:   	0.31%
# (:   	0.28%
# -:   	0.25%
# or:   	0.23%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking
# .:   	0.33%
# and:   	0.33%
# or:   	0.25%
# with:   	0.23%
# (:   	0.21%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on
# a:   	0.26%
# top:   	0.22%
# the:   	0.19%
# each:   	0.19%
# widest:   	0.13%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry
# small:   	0.18%
# strips:   	0.14%
# kitchen:   	0.14%
# point:   	0.13%
# if:   	0.12%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades
# .:   	0.43%
# (:   	0.32%
# ,:   	0.29%
# of:   	0.24%
# or:   	0.23%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging
# to:   	0.4%
# .:   	0.35%
# strips:   	0.31%
# slices:   	0.3%
# down:   	0.27%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed
# slices:   	0.34%
# leaves:   	0.31%
# rounds:   	0.21%
# strips:   	0.2%
# halves:   	0.19%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast
# and:   	0.32%
# .:   	0.28%
# slices:   	0.26%
# with:   	0.26%
# -:   	0.26%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften
# ,:   	0.45%
# .:   	0.37%
# slightly:   	0.37%
# and:   	0.36%
# 1:   	0.31%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would
# to:   	0.14%
# like:   	0.12%
# thinly:   	0.1%
# slightly:   	0.1%
# making:   	0.1%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream
# 1:   	0.33%
# some:   	0.31%
# out:   	0.27%
# slightly:   	0.26%
# to:   	0.24%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure
# to:   	1.32%
# into:   	0.54%
# through:   	0.46%
# .:   	0.44%
# in:   	0.42%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant
# 1:   	0.32%
# tablespoons:   	0.26%
# in:   	0.24%
# mixture:   	0.23%
# into:   	0.22%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful
# of:   	0.24%
# nectar:   	0.18%
# juice:   	0.16%
# pieces:   	0.16%
# tablespoons:   	0.15%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat
# into:   	0.29%
# .:   	0.22%
# to:   	0.22%
# juice:   	0.19%
# on:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep
# .:   	0.41%
# for:   	0.28%
# ,:   	0.25%
# wine:   	0.23%
# in:   	0.22%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops
# .:   	0.79%
# to:   	0.39%
# for:   	0.36%
# ,:   	0.33%
# completely:   	0.33%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations
# .:   	0.64%
# ,:   	0.5%
# in:   	0.31%
# each:   	0.24%
# decoratively:   	0.23%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may
# be:   	0.22%
# not:   	0.15%
# lie:   	0.13%
# visible:   	0.11%
# still:   	0.11%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting
# on:   	0.3%
# end:   	0.23%
# [UNK]:   	0.21%
# food:   	0.2%
# shell:   	0.18%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting matzoh
# completely:   	0.19%
# left:   	0.19%
# rim:   	0.18%
# all:   	0.17%
# base:   	0.17%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting matzoh basic
# lines:   	0.17%
# ,:   	0.16%
# (:   	0.16%
# .:   	0.15%
# to:   	0.14%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting matzoh basic szechwan
# ,:   	0.49%
# -:   	0.46%
# and:   	0.37%
# .:   	0.35%
# (:   	0.33%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting matzoh basic szechwan slightly
# more:   	0.45%
# .:   	0.34%
# thicker:   	0.3%
# with:   	0.28%
# less:   	0.27%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting matzoh basic szechwan slightly oranges
# .:   	0.87%
# in:   	0.57%
# for:   	0.56%
# ,:   	0.55%
# with:   	0.55%
# --------
#
#
# PROMPT: recipe for roasted vegetable | carrots sole collagen clusters similarly either drinks tag thinly basin prince rabe ricotta curly michele try scallops alla tsai preserved vibe wine spinach beards viniagrette sizes carefully overnight crushed seasoned feel raisins enough exposed pack chopped sage briefly meshed jerusalem sap cake ink patches hot around streaked keeps wide dacquoise near cantaloupe timing ) elvis big hair wraps slightly eventually remove thes hands agave whole baskets scooped 8 spoonfuls raking on carry roulades clinging trimmed ¬cast soften would buttercream exposure scant spoonful •baharat steep tops decorations may sitting matzoh basic szechwan slightly oranges parchment
# .:   	0.52%
# ;:   	0.48%
# under:   	0.44%
# ):   	0.39%
# and:   	0.37%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=100, temperature=0.5
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl to blend . add butter and vanilla
#
#
# PROMPT: recipe for chocolate ice cream |
# combine:   	56.66%
# whisk:   	11.53%
# bring:   	8.82%
# in:   	6.05%
# stir:   	5.9%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine
# cream:   	36.4%
# milk:   	20.69%
# all:   	9.99%
# first:   	9.87%
# 1:   	8.13%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries
# ,:   	98.92%
# and:   	1.04%
# in:   	0.03%
# enough:   	0.0%
# with:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries ,
# sugar:   	93.31%
# milk:   	3.47%
# 1:   	0.91%
# cream:   	0.61%
# cherries:   	0.26%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar
# ,:   	98.79%
# and:   	1.21%
# in:   	0.0%
# with:   	0.0%
# syrup:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar ,
# and:   	85.28%
# vanilla:   	3.43%
# cinnamon:   	3.2%
# lemon:   	1.6%
# orange:   	1.12%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and
# vanilla:   	31.82%
# 1:   	31.41%
# salt:   	8.29%
# sugar:   	7.05%
# lemon:   	6.14%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar
# in:   	100.0%
# to:   	0.0%
# and:   	0.0%
# with:   	0.0%
# into:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in
# heavy:   	66.37%
# medium:   	15.27%
# large:   	11.32%
# small:   	4.2%
# a:   	2.31%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium
# bowl:   	86.61%
# saucepan:   	13.21%
# metal:   	0.15%
# pot:   	0.01%
# glass:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl
# .:   	92.96%
# ;:   	6.76%
# to:   	0.15%
# and:   	0.12%
# ,:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl .
# stir:   	59.84%
# bring:   	8.55%
# whisk:   	7.33%
# mix:   	6.22%
# add:   	5.96%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir
# over:   	77.45%
# until:   	11.05%
# in:   	9.53%
# to:   	1.63%
# gently:   	0.12%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over
# medium:   	54.12%
# low:   	45.86%
# very:   	0.01%
# high:   	0.0%
# .:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium
# heat:   	84.12%
# -:   	15.79%
# until:   	0.05%
# .:   	0.02%
# ,:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium -
# low:   	97.11%
# high:   	2.89%
# simmering:   	0.0%
# cream:   	0.0%
# mixture:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low
# heat:   	99.99%
# until:   	0.01%
# flame:   	0.0%
# speed:   	0.0%
# ,:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat
# until:   	99.99%
# just:   	0.01%
# 1:   	0.0%
# ,:   	0.0%
# 2:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until
# sugar:   	99.33%
# mixture:   	0.52%
# butter:   	0.09%
# melted:   	0.02%
# syrup:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar
# dissolves:   	100.0%
# melts:   	0.0%
# is:   	0.0%
# and:   	0.0%
# dissolve:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves
# .:   	92.03%
# and:   	7.73%
# ,:   	0.13%
# ;:   	0.11%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves .
# increase:   	51.69%
# add:   	11.12%
# mix:   	7.29%
# stir:   	6.45%
# bring:   	4.46%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase
# heat:   	99.99%
# speed:   	0.01%
# oven:   	0.0%
# temperature:   	0.0%
# mixture:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat
# and:   	60.32%
# to:   	34.66%
# ;:   	4.92%
# ,:   	0.05%
# .:   	0.03%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and
# boil:   	82.26%
# bring:   	13.55%
# simmer:   	4.05%
# stir:   	0.1%
# cook:   	0.02%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil
# until:   	76.23%
# without:   	22.94%
# 1:   	0.49%
# gently:   	0.07%
# uncovered:   	0.05%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until
# mixture:   	65.52%
# syrup:   	17.83%
# liquid:   	5.52%
# reduced:   	4.84%
# thick:   	2.39%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture
# is:   	77.16%
# thickens:   	22.65%
# just:   	0.06%
# comes:   	0.03%
# boils:   	0.02%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is
# reduced:   	80.67%
# thick:   	6.88%
# very:   	6.43%
# syrupy:   	2.13%
# almost:   	1.97%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced
# to:   	99.94%
# by:   	0.05%
# ,:   	0.01%
# and:   	0.0%
# slightly:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to
# 1:   	91.94%
# 3:   	5.48%
# 2:   	2.27%
# generous:   	0.09%
# scant:   	0.09%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1
# /:   	49.89%
# 1:   	49.16%
# cup:   	0.76%
# 3:   	0.17%
# to:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 /
# 4:   	55.06%
# 2:   	39.08%
# 3:   	5.68%
# 8:   	0.17%
# 1:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3
# cup:   	99.08%
# cups:   	0.77%
# -:   	0.06%
# 1:   	0.05%
# to:   	0.03%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup
# ,:   	99.86%
# at:   	0.1%
# (:   	0.02%
# .:   	0.01%
# and:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup ,
# about:   	91.4%
# stirring:   	8.45%
# 5:   	0.05%
# whisking:   	0.03%
# 1:   	0.02%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about
# 10:   	33.61%
# 5:   	23.5%
# 15:   	14.66%
# 20:   	9.99%
# 1:   	5.88%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5
# minutes:   	100.0%
# hours:   	0.0%
# cups:   	0.0%
# to:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes
# .:   	99.99%
# ;:   	0.0%
# longer:   	0.0%
# (:   	0.0%
# ,:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes .
# remove:   	48.3%
# cool:   	23.57%
# add:   	9.63%
# mix:   	5.49%
# whisk:   	4.09%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove
# from:   	99.69%
# pan:   	0.14%
# cinnamon:   	0.06%
# bowl:   	0.05%
# vanilla:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from
# heat:   	99.97%
# over:   	0.02%
# oven:   	0.0%
# pan:   	0.0%
# water:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat
# .:   	85.79%
# ;:   	11.9%
# and:   	2.21%
# ,:   	0.09%
# using:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat .
# mix:   	27.92%
# whisk:   	20.08%
# add:   	15.22%
# stir:   	13.25%
# cool:   	10.73%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool
# .:   	47.02%
# slightly:   	19.35%
# to:   	14.02%
# mixture:   	12.48%
# completely:   	3.03%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool .
# (:   	49.41%
# mix:   	8.84%
# puree:   	6.61%
# using:   	6.13%
# beat:   	5.86%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix
# in:   	95.46%
# 1:   	1.98%
# sour:   	0.27%
# yogurt:   	0.26%
# chocolate:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in
# vanilla:   	14.45%
# 1:   	12.47%
# raisins:   	10.02%
# orange:   	9.22%
# sour:   	8.39%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins
# .:   	54.51%
# and:   	24.47%
# ,:   	20.77%
# ;:   	0.19%
# (:   	0.04%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins .
# place:   	27.25%
# cool:   	16.88%
# transfer:   	11.36%
# let:   	9.37%
# pour:   	8.92%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place
# 1:   	58.08%
# in:   	8.41%
# remaining:   	7.38%
# 2:   	2.85%
# pork:   	2.84%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1
# cup:   	79.42%
# /:   	11.38%
# 1:   	7.38%
# tablespoon:   	0.95%
# at:   	0.19%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup
# at:   	61.49%
# flour:   	7.66%
# cream:   	5.88%
# sugar:   	4.22%
# warm:   	3.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at
# a:   	93.6%
# least:   	3.15%
# room:   	2.99%
# 1:   	0.23%
# the:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a
# time:   	100.0%
# large:   	0.0%
# sheet:   	0.0%
# strong:   	0.0%
# low:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time
# ,:   	89.99%
# in:   	9.6%
# (:   	0.22%
# .:   	0.11%
# and:   	0.04%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time ,
# in:   	38.15%
# cut:   	12.15%
# pour:   	9.52%
# on:   	7.39%
# over:   	6.79%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in
# warm:   	21.16%
# 1:   	16.42%
# freezer:   	13.33%
# hot:   	11.75%
# enough:   	6.57%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2
# additions:   	82.21%
# batches:   	12.77%
# tablespoons:   	2.88%
# cups:   	0.84%
# large:   	0.55%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions
# ,:   	78.49%
# .:   	18.77%
# each:   	1.78%
# (:   	0.71%
# ;:   	0.09%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions ,
# then:   	71.38%
# and:   	9.2%
# adding:   	4.54%
# alternating:   	2.74%
# 2:   	2.28%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then
# transfer:   	34.79%
# cover:   	23.19%
# divide:   	9.53%
# fold:   	7.44%
# spoon:   	6.37%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover
# and:   	71.11%
# with:   	23.57%
# ;:   	4.61%
# to:   	0.25%
# ,:   	0.13%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and
# refrigerate:   	55.17%
# chill:   	43.91%
# let:   	0.69%
# freeze:   	0.21%
# shake:   	0.01%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate
# until:   	49.79%
# at:   	38.93%
# .:   	7.86%
# overnight:   	2.31%
# for:   	0.66%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at
# least:   	99.85%
# room:   	0.15%
# a:   	0.0%
# low:   	0.0%
# very:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least
# 1:   	55.78%
# 2:   	17.59%
# 4:   	8.09%
# 3:   	6.91%
# 30:   	6.6%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6
# hours:   	100.0%
# minutes:   	0.0%
# days:   	0.0%
# to:   	0.0%
# inches:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours
# .:   	49.5%
# and:   	31.59%
# or:   	15.16%
# ,:   	2.82%
# to:   	0.5%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or
# overnight:   	99.87%
# up:   	0.08%
# freeze:   	0.05%
# until:   	0.0%
# frozen:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight
# .:   	99.48%
# ,:   	0.49%
# (:   	0.02%
# to:   	0.0%
# before:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight .
# preheat:   	54.37%
# (:   	13.17%
# do:   	10.63%
# bring:   	2.77%
# position:   	1.9%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat
# oven:   	99.36%
# broiler:   	0.64%
# to:   	0.01%
# waffle:   	0.0%
# 1:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven
# to:   	100.0%
# and:   	0.0%
# (:   	0.0%
# temperature:   	0.0%
# .:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to
# 350°f:   	85.56%
# 375°f:   	8.29%
# 400°f:   	3.44%
# 325°f:   	1.95%
# 300°f:   	0.3%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f
# .:   	99.99%
# with:   	0.01%
# and:   	0.0%
# (:   	0.0%
# ;:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f .
# butter:   	30.35%
# bake:   	23.52%
# line:   	15.21%
# place:   	7.36%
# spray:   	6.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk
# flour:   	34.45%
# first:   	19.58%
# 1:   	11.84%
# egg:   	9.08%
# 3:   	7.61%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour
# ,:   	98.72%
# and:   	1.28%
# in:   	0.0%
# brown:   	0.0%
# mixture:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour ,
# baking:   	52.75%
# sugar:   	36.73%
# butter:   	3.88%
# cornmeal:   	1.43%
# salt:   	1.13%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking
# powder:   	95.58%
# soda:   	4.41%
# sheets:   	0.0%
# flour:   	0.0%
# egg:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder
# ,:   	97.36%
# and:   	2.64%
# in:   	0.0%
# .:   	0.0%
# over:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder ,
# and:   	72.25%
# baking:   	21.35%
# salt:   	4.69%
# cinnamon:   	0.69%
# 1:   	0.48%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and
# salt:   	93.1%
# baking:   	4.69%
# 1:   	1.53%
# 2:   	0.2%
# cinnamon:   	0.15%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt
# in:   	99.88%
# into:   	0.12%
# .:   	0.0%
# on:   	0.0%
# to:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in
# medium:   	73.1%
# large:   	23.29%
# another:   	1.74%
# small:   	0.8%
# processor:   	0.62%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium
# bowl:   	100.0%
# saucepan:   	0.0%
# metal:   	0.0%
# -:   	0.0%
# skillet:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl
# to:   	96.34%
# .:   	2.93%
# until:   	0.71%
# ;:   	0.01%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl to
# blend:   	99.95%
# combine:   	0.04%
# medium:   	0.01%
# coat:   	0.0%
# high:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl to blend
# .:   	99.9%
# ;:   	0.07%
# well:   	0.02%
# ,:   	0.0%
# (:   	0.0%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl to blend .
# mix:   	30.81%
# add:   	17.77%
# using:   	15.47%
# whisk:   	13.59%
# beat:   	12.28%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl to blend . add
# butter:   	71.35%
# 1:   	5.62%
# eggs:   	5.08%
# flour:   	4.75%
# egg:   	4.74%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl to blend . add butter
# and:   	76.39%
# ;:   	21.21%
# ,:   	1.49%
# mixture:   	0.42%
# .:   	0.29%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | combine cranberries , sugar , and sugar in medium bowl . stir over medium - low heat until sugar dissolves . increase heat and boil until mixture is reduced to 1 / 3 cup , about 5 minutes . remove from heat . cool . mix in raisins . place 1 cup at a time , in 2 additions , then cover and refrigerate at least 6 hours or overnight . preheat oven to 350°f . whisk flour , baking powder , and salt in medium bowl to blend . add butter and
# rub:   	25.85%
# process:   	18.32%
# shortening:   	12.94%
# mix:   	12.29%
# beat:   	11.37%
# --------

# %%
info = text_generator.generate(
    "recipe for chocolate ice cream |", max_tokens=100, temperature=5.0
)
print_probs(info, vocab)
# Out:
# generated text:
# recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert coke jelly sangría breakfast recommended sorrel
#
#
# PROMPT: recipe for chocolate ice cream |
# combine:   	0.39%
# whisk:   	0.33%
# bring:   	0.32%
# in:   	0.31%
# stir:   	0.31%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw
# together:   	0.25%
# peel:   	0.21%
# in:   	0.18%
# nuts:   	0.17%
# zest:   	0.17%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves
# in:   	0.56%
# and:   	0.31%
# of:   	0.28%
# ,:   	0.28%
# .:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge
# in:   	0.35%
# and:   	0.31%
# -:   	0.25%
# (:   	0.22%
# to:   	0.22%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes
# room:   	0.14%
# hot:   	0.12%
# grainy:   	0.11%
# lukewarm:   	0.11%
# fine:   	0.11%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces
# just:   	0.31%
# to:   	0.29%
# .:   	0.24%
# and:   	0.24%
# by:   	0.24%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia
# .:   	0.53%
# in:   	0.48%
# into:   	0.35%
# ;:   	0.34%
# and:   	0.31%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance
# ,:   	0.59%
# and:   	0.4%
# .:   	0.38%
# ;:   	0.3%
# with:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin
# ,:   	0.52%
# and:   	0.5%
# .:   	0.43%
# in:   	0.36%
# ;:   	0.34%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe
# .:   	0.75%
# and:   	0.62%
# ,:   	0.54%
# with:   	0.4%
# ;:   	0.4%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver
# and:   	0.73%
# in:   	0.56%
# ,:   	0.49%
# (:   	0.45%
# by:   	0.44%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak
# in:   	0.26%
# at:   	0.25%
# layers:   	0.25%
# slices:   	0.21%
# between:   	0.18%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas
# .:   	0.65%
# ,:   	0.62%
# and:   	0.56%
# in:   	0.37%
# with:   	0.35%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i
# .:   	0.8%
# ,:   	0.71%
# and:   	0.57%
# with:   	0.38%
# (:   	0.38%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes
# .:   	0.9%
# and:   	0.82%
# in:   	0.82%
# ,:   	0.77%
# on:   	0.54%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this
# .:   	0.42%
# in:   	0.38%
# ,:   	0.31%
# and:   	0.28%
# or:   	0.19%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure
# .:   	0.7%
# in:   	0.53%
# ,:   	0.52%
# and:   	0.49%
# (:   	0.37%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo
# .:   	0.6%
# and:   	0.45%
# (:   	0.39%
# ,:   	0.38%
# in:   	0.34%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of
# the:   	0.19%
# bread:   	0.16%
# coconut:   	0.14%
# each:   	0.13%
# long:   	0.13%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too
# much:   	0.31%
# thick:   	0.24%
# long:   	0.21%
# many:   	0.17%
# using:   	0.17%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half
# .:   	0.47%
# and:   	0.42%
# of:   	0.34%
# ,:   	0.32%
# (:   	0.28%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic
# .:   	0.69%
# and:   	0.32%
# (:   	0.29%
# ,:   	0.21%
# ;:   	0.19%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together
# .:   	1.07%
# and:   	0.62%
# ,:   	0.6%
# in:   	0.4%
# (:   	0.35%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler
# in:   	0.9%
# .:   	0.74%
# ,:   	0.67%
# or:   	0.57%
# and:   	0.55%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear
# a:   	0.53%
# with:   	0.51%
# the:   	0.43%
# .:   	0.38%
# warm:   	0.34%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato
# mixture:   	0.42%
# .:   	0.41%
# in:   	0.34%
# with:   	0.3%
# and:   	0.29%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch
# and:   	0.55%
# ,:   	0.49%
# .:   	0.48%
# over:   	0.48%
# in:   	0.45%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes
# .:   	0.88%
# and:   	0.6%
# ,:   	0.54%
# in:   	0.5%
# over:   	0.5%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade
# .:   	0.8%
# ,:   	0.63%
# and:   	0.61%
# in:   	0.45%
# over:   	0.43%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts
# to:   	0.48%
# or:   	0.3%
# edge:   	0.25%
# out:   	0.25%
# with:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte
# with:   	0.72%
# to:   	0.55%
# or:   	0.41%
# in:   	0.4%
# on:   	0.39%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously
# with:   	0.57%
# on:   	0.38%
# .:   	0.34%
# over:   	0.32%
# in:   	0.32%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly
# .:   	0.9%
# ,:   	0.62%
# and:   	0.55%
# or:   	0.42%
# over:   	0.37%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over
# the:   	0.22%
# .:   	0.19%
# top:   	0.15%
# both:   	0.13%
# its:   	0.13%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida
# .:   	0.41%
# ,:   	0.28%
# ;:   	0.18%
# or:   	0.15%
# from:   	0.15%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese
# to:   	1.11%
# -:   	0.26%
# (:   	0.25%
# ,:   	0.25%
# slightly:   	0.24%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists
# ,:   	1.19%
# .:   	0.82%
# and:   	0.62%
# of:   	0.62%
# to:   	0.61%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh
# to:   	0.42%
# .:   	0.31%
# ,:   	0.3%
# meal:   	0.29%
# and:   	0.27%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to
# the:   	0.19%
# form:   	0.15%
# make:   	0.14%
# bake:   	0.14%
# remove:   	0.13%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina
# .:   	0.49%
# ,:   	0.35%
# mixture:   	0.29%
# opposite:   	0.25%
# each:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey
# .:   	0.64%
# (:   	0.31%
# ,:   	0.29%
# for:   	0.25%
# ;:   	0.25%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english
# ':   	0.23%
# .:   	0.18%
# muffins:   	0.13%
# form:   	0.12%
# -:   	0.11%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit
# ,:   	0.28%
# .:   	0.27%
# at:   	0.24%
# or:   	0.23%
# for:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos
# .:   	0.24%
# at:   	0.23%
# ,:   	0.2%
# (:   	0.15%
# higher:   	0.14%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely
# .:   	0.65%
# ,:   	0.42%
# in:   	0.31%
# until:   	0.31%
# at:   	0.29%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop
# filling:   	0.17%
# the:   	0.14%
# sauce:   	0.14%
# mixture:   	0.14%
# custard:   	0.14%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet
# .:   	0.73%
# in:   	0.29%
# and:   	0.25%
# ,:   	0.24%
# for:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina
# .:   	0.49%
# ,:   	0.45%
# to:   	0.44%
# until:   	0.39%
# and:   	0.33%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina {
# a:   	0.19%
# ,:   	0.19%
# in:   	0.17%
# consistency:   	0.16%
# and:   	0.16%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat
# and:   	0.35%
# ;:   	0.3%
# ,:   	0.25%
# .:   	0.25%
# but:   	0.22%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level
# .:   	0.31%
# in:   	0.3%
# and:   	0.26%
# ,:   	0.25%
# ;:   	0.23%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged
# to:   	0.46%
# across:   	0.42%
# around:   	0.36%
# ,:   	0.3%
# at:   	0.29%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo
# is:   	0.23%
# at:   	0.17%
# end:   	0.16%
# are:   	0.16%
# pack:   	0.16%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco
# to:   	0.81%
# and:   	0.38%
# is:   	0.29%
# as:   	0.28%
# between:   	0.28%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs
# and:   	0.77%
# ,:   	0.59%
# to:   	0.56%
# together:   	0.37%
# ;:   	0.36%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops
# of:   	0.37%
# are:   	0.35%
# is:   	0.32%
# and:   	0.31%
# should:   	0.27%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert
# ):   	0.43%
# and:   	0.43%
# ;:   	0.23%
# to:   	0.23%
# .:   	0.22%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert coke
# ):   	0.56%
# will:   	0.33%
# and:   	0.32%
# for:   	0.32%
# .:   	0.27%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert coke jelly
# ):   	0.97%
# will:   	0.38%
# -:   	0.33%
# ':   	0.32%
# is:   	0.3%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert coke jelly sangría
# ):   	1.17%
# is:   	0.36%
# will:   	0.36%
# .:   	0.33%
# with:   	0.32%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert coke jelly sangría breakfast
# ):   	0.82%
# in:   	0.36%
# is:   	0.34%
# if:   	0.3%
# will:   	0.27%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert coke jelly sangría breakfast recommended
# ):   	0.5%
# slightly:   	0.29%
# is:   	0.29%
# by:   	0.26%
# for:   	0.24%
# --------
#
#
# PROMPT: recipe for chocolate ice cream | throw dissolves porridge becomes reduces tilapia substance gratin rabe sliver peak tortillas i galettes this unsure adobo of too half balsamic together boiler smear tomato punch prunes tapenade starts torte generously swiftly over florida bolognese twists matzoh to semolina smokey english sit huevos indefinitely atop filet caponatina { meat level dragged hobo tabasco slabs dollops desert coke jelly sangría breakfast recommended sorrel
# ):   	0.79%
# per:   	0.34%
# on:   	0.28%
# will:   	0.27%
# (:   	0.24%
# --------
